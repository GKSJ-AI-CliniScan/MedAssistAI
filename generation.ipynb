# %%
import pandas as pd

df = pd.read_csv("backend/ml/datasets/filtered_240_disease_dataset.csv")

diseases = sorted(df["diseases"].unique())

print(len(diseases))
# Out:
# 240

# %%
pd.DataFrame({"Disease": diseases}).to_csv("disease_list.csv", index=False)
