# %%
import pandas as pd
import numpy as np
import os

# %%
import os

os.chdir(r"C:\Users\admin\Desktop\MedAssist AI")

print(os.getcwd())
# Out:
# C:\Users\admin\Desktop\MedAssist AI

# %%
os.listdir("datasets/Dataset_3_SymptomsToDisease")
# Out:
# ['data.csv', 'final_symptoms_to_disease.csv']

# %%
dataset3_df = pd.read_csv("datasets/Dataset_3_SymptomsToDisease/final_symptoms_to_disease.csv")

# %%
dataset3_df.shape
# Out:
# (192715, 2)

# %%
dataset3_df.head()
# Out:
#          diseases                                       symptom_text
# 0  panic disorder  anxiety and nervousness, shortness of breath, ...
# 1  panic disorder  shortness of breath, depressive or psychotic s...
# 2  panic disorder  anxiety and nervousness, depression, shortness...
# 3  panic disorder  anxiety and nervousness, depressive or psychot...
# 4  panic disorder  anxiety and nervousness, depression, insomnia,...

# %%
dataset3_df.isnull()
# Out:
#         diseases  symptom_text
# 0          False         False
# 1          False         False
# 2          False         False
# 3          False         False
# 4          False         False
# ...          ...           ...
# 192710     False         False
# 192711     False         False
# 192712     False         False
# 192713     False         False
# 192714     False         False
#
# [192715 rows x 2 columns]

# %%
dataset3_df.isnull().sum()
# Out:
# diseases        0
# symptom_text    0
# dtype: int64

# %%
dataset3_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192715 entries, 0 to 192714
# Data columns (total 2 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   diseases      192715 non-null  object
#  1   symptom_text  192715 non-null  object
# dtypes: object(2)
# memory usage: 2.9+ MB

# %%
dataset3_df.duplicated().sum()
# Out:
# np.int64(28988)

# %%
dataset3_df.describe(include="all")
# Out:
#         diseases                           symptom_text
# count     192715                                 192715
# unique       254                                 149241
# top     cystitis  shortness of breath, sharp chest pain
# freq        1219                                     18

# %%
dataset3_df["diseases"].nunique()
# Out:
# 254
